# %% [markdown]
# # COGS 108 - Final Project - The Effects of NFL Team Performance on Regular Season MVP Vote Share for Quarterbacks
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://drive.google.com/file/d/1lz3M9zu2V4A3hZZqvAiF7dUEnjN6eDgE/view?usp=sharing
#
# ## Abstract
#
# In this project, we explored how team-level factors influenced the share of MVP votes that are received by the quarterbacks (QB) in the National Football League (NFL). While the Most Valuable Player (MVP) award is given to an individual player, the quarterback's success does rely on the whole team around them because they operate within them. We focused on team factors such as defensive performance, offensive lineman, and strength of schedule which helps determine whether it affects the MVP vote share. To study this, we merged various datasets which included the MVP voting results, defensive stats, team standings, and the quarterback's season statistics from the years of 2000-2025. Once we cleaned and merged the data, we used graphs, permutation tests and correlations to examine the relationship between the MVP vote share and team-level variables.
#
# To further evaluate, results indicate that team-level factors are strongly correlated with MVP vote share than individual quarterback's personal statistics. When quarterbacks are against teams with stronger defenses and allow fewer points compared to higher points, they tend to receive higher shares of MVP votes. To see those patterns in the data, we explored that data, exploratory data analysis (EDA) by using summary statistics and graphs. In order to show that, we used correlation analysis to measure the relationship between both MVP vote share and team performance factors. Finally, we used permutation test to indicate whether the differences between top MVP candidates and the other quarterback's were statistically significant.
#
# The permutation tests showed that team performance such as strength of schedule, defensive statistics, and points allowed showed signs of statistically significant compared to individual performance such as touchdown-to-interception ratio between the groups. This shows how significant team performance is when it comes down to MVP voting. Our results indicate that MVP voting is determined by both the quarterback's performance and also the team's success as well as the team-level factors. Voters may take into consideration the team's performance when deciding an individual quarterback.

# %% [markdown]
# ## Authors
#
# - Max Kupka: Analysis, Writing – original draft, Writing – review & editing, Project administration
#
# - Kameron Rajaofetra: Project administration, Background research, Conceptualization, Visualization, Data curation, Writing – original draft
#
# - Ty Albao: Software, Analysis, Writing – original draft, Data curation
#
# - Jacqueline Cervantes-Nava: Analysis, Writing – original draft, Organization, Writing – review & editing
#
# - Brandon Van Horn: Software, Analysis, Writing – original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# To what extent do team-level contextual factors such as offensive line protection and sack rates (percentage of how often the quarterback is tackled behind the line of scrimmage per play), strength of schedule (measured by the average quality of their opponents, based on a formula called Simple Rating System (SRS)), and team defensive performance (measured by defensive SRS) influence the percentage of 1st place regular season MVP votes for quarterbacks since 2000?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# IMPORTANT TERMS AND ABBREVIATIONS TO KNOW:
#
# 1. Associated Press Most Valuable Player Award (NFL AP MVP): This is an annual award presented by the Associated Press to a player in the National Football League judged to have been the most valuable in that year's regular season (distinct from the superbowl MVP, the most valuable player in the superbowl).
# 2. Quarterback: A player positioned behind the ball before a play starts who directs a team's offensive play. This usually involves throwing the ball to a teammate down the field, but can also involve holding onto the ball and running it down the field if no teammates are open.
# 3. Running Back: An offensive player who specializes in running the ball down the field, distinct from quarterbacks who usually throw the ball, and wide receivers who usually catch the ball. In rare cases, running backs have won the NFL AP MVP award, although this has only happened 4 times since 2000. Since this study is based on factors that influence a quarterback being selected as MVP, we will disregard running backs who won the MVP award for their year and only pay attention to the top 3 quarterbacks from that year.
# 4. Offensive Line: A group of players on the quarterbacks team who shield him from the other team's defense, giving him adequate time to throw the ball down the field. A strong offensive line can greatly increase a quarterbacks performance, although we want to measure the extent to which this is true.
# 5. Sack: Occurs when the defense tackles the quarterback behind the line of scrimmage before they can throw a forward pass, or forces them out of bounds behind that line. It results in a loss of yardage for the offense and is a major defensive play that shifts momentum.
# 6. Touchdown: The primary scoring play in American football, worth 6 points. It occurs when a player legally gains possession of the ball in the opponent's end zone, either by carrying it across the goal line or catching a pass while in the end zone.
# 7. Field Goal: A 3-point scoring play, usually attempted on fourth down when the offense is close enough to the opponent's end zone but unable to score a touchdown. A kicker must place-kick or drop-kick the ball through the opponent's goalposts, passing above the crossbar and between the uprights.
# 8. Downs: A down in American football is one of four permitted attempts (plays) for the offense to advance the ball at least 10 yards toward the opponent’s end zone. If the team gains 10 or more yards, they earn a new set of four downs (a "first down"). Failing to gain 10 yards in four downs results in a turnover where the other team receives the ball.
# 9. Points Allowed Per Game: Points Allowed per Game (PA/G) in football is a defensive statistic representing the average number of points a team's defense surrenders to opponents per game over a specific period, calculated as Total Points Allowed / Games Played. It measures defensive efficiency, with lower averages indicating a stronger defense.
# 10. Interception: A defensive play in American football where a defender catches a forward pass intended for an offensive receiver, resulting in an immediate turnover. It stops the offense's drive, awards the defense possession, and allows the defender to return the ball for potential yards or a touchdown.
#
# The National Football League, known in short as the NFL, is the premier sports league that plays the sport known as gridiron football or American football. It is the most popular sport in the United States by a large margin, and drew average viewership of 18.7 million viewers per game in the 2025 NFL Season.<a name="cite_note-1"></a> [^](#cite_ref-1) The sport is played on a 100 yard field with two teams pitted against each other, with the winner being the team whose score is highest after four 15 minute quarters have passed. One side, the offense, carriers the football and aims to make it into the opposing teams endzone to score points whether that is through field goals or touchdowns. The other side, the defense, does everything possible to stop or reverse the advancements of the offense. Among the various accolades and awards that are given in the NFL, only two remain at the top of every players list. The Super Bowl trophy itself, given to the champions of the football league, and the NFL Associated Press Most Valuable Player Award (abbreviated to NFL AP MVP). The latter is of most interest to us, as it has become a topic of much controversy following recent NFL seasons.
#
# The NFL Associated Press Most Valuable Player Award is the most prestigious individual honor in professional American football, recognizing the player who provided the highest value to their team's success during the regular season. Voted on by a 50-person media panel, it highlights exceptional performance, usually for a top-performing quarterback on a winning team, and serves as a major accolade during the annual NFL Honors ceremony. However, this award is subject to a lot of controversy as many raise questions if the performance of the team surrounding MVP candidates is indirectly more valuable in the selection process than the skill of the player selected.
#
# The 2025 NFL AP MVP race between Matthew Stafford (QB Rams) and Drake Maye (QB Patriots) already has many individuals racing to find different variables that affect MVP selection. One of these variables is the strength of schedule, a statistic that is determined by summing the win-loss records (or winning percentages) of all of a team's opponents from the previous season. Patriots have the 3rd easiest strength of schedule, while the Rams have tied for the 18th strength of schedule. While it's worth noting that Stafford did in fact receive the most recent MVP award, previous MVP winners have faced very easy teams such as four time MVP Aaron Rodgers with the Green Bay Packers.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)
#
# Another factor that is critical to the performance of previous MVP winners is the strength of the offensive line. The offensive line is composed of five players whose responsibility is to always protect the quarterback from defensive pressures and sacks. These players are: center, left guard, left tackle, right guard, and right tackle. A successful offensive line ensures that the pocket does not falter, preventing pressures and sacks that would hurt offensive progress made by either quarterback or running back.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3)
#
# An overlooked statistic in MVP odds is defensive performance.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) On the surface, the defense of a team might not account for much in the way of offense. However, a good defense can stop a team short and force a punt that places the offense much closer to the endzone than expected. As a result, the defense is a critical component of the success of an offense, and by extension the MVP candidate. A strong defense is able to turn the ball over to the offense, giving more opportunities for the offense to score with elaborate plays.
#
# So, what makes our project different from the ones that came before? The main factor of this project that differentiates us boils down to the variables we are paying attention to. Unlike previous projects which have explored the correlation between NFL MVP selection odds and metrics that evaluate quarterback performance (like touchdown points thrown), all the variables we listed above (strength of schedule, offensive line strength, and defensive performance) are not directly tied to quarterbacks. However, these variables are still known to influence quarterback performances, and by extension, their odds of being selected as MVP candidates. In this project, we plan to document the role team performance plays in the NFL MVP candidate selection process, despite the award only going to a single individual.
#
# ### References
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1)  NFL viewership up 10% this season at 18.7M per game
#     https://www.espn.com/nfl/story/_/id/47541246/nfl-viewership-10-percent-season-187m-per-game
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) NFL MVP Winners and Their Teams’ Rank in Strength of Schedule.
#    https://www.reddit.com/r/NFLv2/comments/1pznfpj/nfl_mvp_winners_and_their_teams_rank_in_strength/
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) NFL Study: How Important Is Offensive Line Success?
#    https://nflspinzone.com/2022/09/07/nfl-study-important-offensive-line-success/
#
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Why Are Defensive Players Forgotten When It Comes to NFL MVP?
#    https://bleacherreport.com/articles/88241-why-are-defensive-players-forgotten-when-itcomes-to-nfl-mvp

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Among the top three NFL MVP candidates who happen to be quarterbacks each year since 2000, lower offensive line pressure and sack rates (measured by percentage of sacks per play), an easier strength of schedule (measured by win percentages of opposing teams last season), and lower points allowed per game by team defenses (measured by average points allowed per game during a season) will be associated with a higher regular-season MVP vote share. This hypothesis is based on prior research suggesting that quarterback performance is influenced by team factors such as pass protection and defensive support, which can inflate traditional performance metrics. For example, a strong offensive line that minimizes sack rates on the quarterback gives the quarterback more time to make good throws, an easier strength of schedule allows the quarterback to accumulate better stats by playing against weaker defenses, and a strong team defense will strip the ball from the opposing offense to give the quarterback more play time. Since MVP voting often reflects both individual performance and team success, quarterback MVP candidates benefiting from an all around good team are expected to receive a greater share of MVP votes.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: AP NFL Most Valuable Player Voting Results (2000–2024)
#   - Link to the dataset: https://www.pro-football-reference.com/awards/ap-nfl-mvp-award.htm
#   - Number of observations: 87
#   - Number of variables: 14
#   - Description of the variables most relevant to this project:
#       - Year: The NFL regular season year in which MVP voting occurred
#       - Player: Name of the player receiving MVP votes
#       - Pos: Player position (filtered to quarterbacks for this project)
#       - Tm: Team the player represented during that season
#       - Vote Pts: Total weighted voting points received from AP voters
#       - 1st Place Votes: Number of first-place MVP votes received
#       - Share: Percentage of total possible MVP voting points earned by the player (value between 0 and 1). A value closer to 1 indicates stronger voter consensus, while values near 0 indicate minimal support. This variable will serve as the dependent variable in our analysis.
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#       - The dataset only includes players who received MVP votes, excluding the majority of quarterbacks each season. This creates selection bias and limits analysis to MVP candidates rather than all quarterbacks.
#       - MVP voting is subjective and influenced by media narratives, team success, and public perception, meaning vote share does not reflect performance metrics alone.
#       - The relatively small sample size (87 quarterback-season observations) limits the complexity of regression models that can be applied.
#       - Beginning with the 2022 season, MVP voting changed from a single-choice ballot to a ranked-choice system (voters rank their top five players), which affects how vote share is distributed across candidates compared to earlier seasons.
#
#
# - Dataset #2
#   - Dataset Name: NFL Standings and Team Stats (2000–2024)
#   - Link to the dataset: https://www.pro-football-reference.com/years/2025/index.htm
#   - Number of observations: 830
#   - Number of variables: 14
#   - Description of the variables most relevant to this project:
#       - Tm: Team name for that season
#       - W: Number of games won during the regular season
#       - L: Number of games lost during the regular season
#       - T: Number of games tied (added beginning in 2002)
#       - W-L%: Winning percentage (wins divided by total games played)
#       - PF: Total points scored by the team during the regular season
#       - PA: Total points allowed by the team during the regular season
#       - PD: Point differential (points scored minus points allowed)
#       - MoV: Margin of Victory, the average point differential per game
#       - SoS: Strength of Schedule, measuring the average quality of opponents based on SRS values
#       - SRS: Simple Rating System, a composite metric estimating overall team strength in points above or below league average
#       - OSRS: Offensive Simple Rating System, estimating offensive contribution to team strength
#       - DSRS: Defensive Simple Rating System, estimating defensive contribution to team strength
#   - Descriptions of any shortcomings this dataset has with respect to the project:
#       - Team names vary across seasons due to franchise relocations (e.g. STL to LA, SD to LA, OAK to LV), requiring standardization before merging.
#       - Table structure changes slightly in earlier seasons (absence of tie column prior to 2002), requiring additional data wrangling for consistency.
#       - SRS and its components are composite metrics, which may introduce multicollinearity if used alongside raw scoring statistics.
#       - Team-level statistics reflect overall team performance and may not fully isolate quarterback-specific effects.
#
#
# - Dataset #3
#   - Dataset Name: NFL Opposition and Defensive Statistics
#   - Link to the dataset: https://www.pro-football-reference.com/years/2025/opp.htm
#   - Number of observations: 830
#   - Number of variables: 29
#   - Description of the variables most relevant to this project:
#       - G: Games played by this team
#       - Cmp%: Average Percentage of passes completed by opponent offense against this team
#       - Yds: Yards gained by passing by opponent offense against this team
#       - TD: Passing touchdowns scored against this team
#       - TD%: Average Percentage of touchdowns thrown when attempting to pass against this team
#       - Int: Number of interceptions thrown against this team (An interception occurs when the ball is caught by a defensive player, turning possession of the ball to the other team)
#       - Int%: Percentage of interceptions made when opposing team attempts to pass
#       - Y/A: Average Yards gained per pass attempt by opponent
#       - Y/G: Average Yards gained per game by opponent
#       - Sk: Number of times opponent quarterback was sacked
#       - TFL: Number of tackles per loss, meaning the opposing offense was pushed back during the play
#   - Descriptions of any shortcomings this dataset has with respect to the project: No shortcomings detected
#
# - Dataset #4
#   - Dataset Name: Player Season and Career Stats
#   - Link to the dataset: https://www.sports-reference.com/stathead/football/player-season-finder.cgi?request=1&order_by=qb_w
#   - Number of observations: 2042
#   - Number of variables: 9
#   - Description of the variables most relevant to this project:
#       - Player: Quarterback name
#       - Season: Year of the season
#       - Age: Age of quarterback
#       - Team: Team name the quarterback played for
#       - G: Games played
#   - Descriptions of any shortcomings this dataset has with respect to the project: No shortcomings detected

# %% [markdown]
# ### MVP Winners by Year (Dataset 1)
#
# The dataset from Pro-Football-Reference documents winners of the Associated Press (AP) NFL Most Valuable Player Award, given annually to the player judged most valuable in the National Football League. Each row represents a single NFL season, making the primary unit of analysis the year. The key variables include the season (Year), the player’s name, position (such as QB for quarterback or RB for running back), team, and a link to detailed voting results. Because the award is decided by media voting, the dataset captures both performance recognition and historical context rather than raw game statistics alone.
#
# The most important metrics associated with this dataset relate to voting outcomes. Voting data typically includes total vote points, number of first-place votes, and vote share (the percentage of possible votes received). These are measured in counts (number of votes) and percentages (vote share). A higher vote share indicates a stronger consensus among voters that a player was the most valuable that season. While the main table lists only winners, the linked voting pages provide additional context about how dominant a player’s season was relative to other candidates. For example, players such as Peyton Manning and Aaron Rodgers have won multiple MVP awards, suggesting sustained high-level performance across several seasons.
#
# There are some potential limitations to consider when analyzing this dataset. First, the MVP award is based on subjective voting rather than a purely objective formula, which introduces potential bias. Media narratives, team success, popularity, and positional importance may influence outcomes. Second, the dataset only lists winners in the main table, which can obscure close races or strong performances by runners-up unless additional voting pages are consulted. Third, historical comparisons across eras may be difficult because the NFL has evolved significantly over time. Rule changes, season length, and offensive styles have all shifted, making raw statistical comparisons imperfect. Finally, because the dataset focuses solely on award outcomes, it does not capture the full distribution of player performance across the league, limiting its usefulness for comprehensive statistical modeling without additional supplemental data.

# %%
## Cleaning MVP Votes (2000-2025) and Filtering for Quarterbacks
import pandas as pd

years = range(2000, 2026)
votes_df_list = list()

for year in years:
    votes_df = pd.read_csv(f'data/00-raw/mvp_voting/mvp_voting_{year}.csv', header=1)
    votes_df['year'] = year

    if year < 2022:
        votes_df.rename(columns={'Votes':'1st Place'}, inplace=True)
    votes_df_list.append(votes_df)

all_votes = pd.concat(votes_df_list)

cols_to_drop = [
    'Att.1',
    'Yds.1',
    'TD.1',
    'Rec',
    'Yds.2',
    'TD.2',
    'Solo',
    'Sk',
    'Int.1',
    '-9999',
    'Vote Pts'
]
cols_rename = {
    '1st Place': '1st_Place_Votes'
}

# dropping and renaming columns
qb_votes = all_votes.drop(columns=cols_to_drop)
qb_votes.rename(columns = cols_rename, inplace=True)

# changing share % metric
qb_votes['Share'] = qb_votes.groupby('year')['1st_Place_Votes'].transform(lambda x: x / x.sum())

# filtering to select only Quarterbacks, resetting index
qb_votes = qb_votes[qb_votes['Pos']=='QB']
qb_votes.reset_index(drop=True, inplace=True)

# qb_votes.to_csv('data/02-processed/qb_mvp_votes.csv', index=False)
qb_votes
# Out:
#     Rk Pos            Player                    Tm  1st_Place_Votes  Share  \
# 0    2  QB    Donovan McNabb   Philadelphia Eagles             11.0   0.22
# 1    4  QB       Rich Gannon       Oakland Raiders              5.0   0.10
# 2    6  QB    Peyton Manning    Indianapolis Colts              1.0   0.02
# 3    1  QB       Kurt Warner        St. Louis Rams             21.5   0.43
# 4    3  QB       Brett Favre     Green Bay Packers              5.0   0.10
# ..  ..  ..               ...                   ...              ...    ...
# 82   1  QB  Matthew Stafford      Los Angeles Rams             24.0   0.48
# 83   2  QB        Drake Maye  New England Patriots             23.0   0.46
# 84   3  QB        Josh Allen         Buffalo Bills              2.0   0.04
# 85   5  QB   Trevor Lawrence  Jacksonville Jaguars              0.0   0.00
# 86   6  QB    Justin Herbert  Los Angeles Chargers              1.0   0.02
#
#      G  GS  Cmp  Att   Yds  TD  Int  year
# ...

# %% [markdown]
# ### NFL Standings and Team Stats (Dataset 2)
#
# This dataset aggregates a wide range of team and league-level data for the 2025 National Football League season, making it valuable for analyzing team performance and trends across the league. At its core, the dataset includes standings and basic team statistics, with key metrics like Wins (W), Losses (L), Ties (T), and Winning Percentage (W-L%) that measure how each team performed over the regular season. It also shows Points For (PF) and Points Against (PA), which are the total points a team scored and allowed. These are measured in simple unit counts of points scored during games. Other derived metrics include Point Differential (PD), which is PF minus PA and gives a sense of overall team dominance, and Strength of Record (SoS) or Simple Rating System (SRS), advanced measures that adjust performance for schedule difficulty.
#
# Beyond standings, the page links to a host of offensive and defensive statistical categories, including passing, rushing, scoring, and special teams. For example, individual leaders in passing yards help indicate which players contributed most in the air, while team totals for passing yards, rushing yards, points scored, and total yards reveal offensive profiles across the league. Passing yards are counted in yards gained through completed throws, while rushing yards count ground gains. Both are measured in units of yards gained. Points scored encompasses all scoring methods (touchdowns, field goals, extra points) and is presented in total point units, offering a snapshot of offensive effectiveness.
#
# While the dataset is comprehensive, there are some limitations to keep in mind. First, the page aggregates a very broad set of metrics but does not always show game-level or situation-specific nuances (like performance in clutch situations or under certain conditions). This could mask variability that’s important in deeper analytics. Second, some advanced metrics rely on derived formulas or assumptions (like SRS or Strength of Schedule), which can incorporate model bias or might not reflect real competitive balance perfectly. Third, because this view is a season summary, it cannot capture mid-season changes (such as injuries, trades, or coaching changes) without drilling down into game-by-game tables. Finally, the dataset is retrospective. It reflects the end results of a season, but doesn’t directly explain why certain teams performed the way they did, especially since many contributing factors (like in-game decision making or individual player context) aren’t encoded.

# %%
## Data Wrangling: Converting Raw Standings to Time-Series Format
with open('data/00-raw/season_standings_raw.csv') as f:
    lines = f.readlines()

with open('data/00-raw/season_standings.csv', 'w') as f:
    f.write('Tm,W,L,T,W-L%,PF,PA,PD,MoV,SoS,SRS,OSRS,DSRS,Year\n')

    for line in lines:
        line = line.strip()

        if line.isdigit():
            year = line
            continue

        if line.startswith('Tm'):
            continue

        if line:
            parts = line.split(',')

            if len(parts) == 12:
                parts.insert(3, '0')  # insert T=0 after L

            f.write(','.join(parts) + f',{year}\n')

standings = pd.read_csv('data/00-raw/season_standings.csv')
standings['Tm'] = standings['Tm'].str.strip('*+')

# standings.to_csv('data/02-processed/season_standings.csv', index=False)
standings
# Out:
#                        Tm   W   L  T   W-L%   PF   PA   PD   MoV  SoS   SRS  \
# 0          Miami Dolphins  11   5  0  0.688  323  226   97   6.1  1.0   7.1
# 1      Indianapolis Colts  10   6  0  0.625  429  326  103   6.4  1.5   7.9
# 2           New York Jets   9   7  0  0.563  321  321    0   0.0  3.5   3.5
# 3           Buffalo Bills   8   8  0  0.500  315  350  -35  -2.2  2.2   0.0
# 4    New England Patriots   5  11  0  0.313  276  338  -62  -3.9  1.4  -2.5
# ..                    ...  ..  .. ..    ...  ...  ...  ...   ...  ...   ...
# 825    New Orleans Saints   6  11  0  0.353  306  383  -77  -4.5 -0.3  -4.9
# 826      Seattle Seahawks  14   3  0  0.824  483  292  191  11.2  1.6  12.8
# 827      Los Angeles Rams  12   5  0  0.706  518  346  172  10.1  2.4  12.5
# 828   San Francisco 49ers  12   5  0  0.706  437  371   66   3.9  2.1   6.0
# 829     Arizona Cardinals   3  14  0  0.176  355  488 -133  -7.8  3.4  -4.4
#
#      OSRS  DSRS  Year
# 0     0.0   7.1  2000
# ...

# %% [markdown]
# ### NFL Opposition and Defensive Statistics (Dataset 3)
#
# The dataset contains the NFL Opposition and Defensive Statistics of each team by season. Each row represents a single NFL team in one season (observation = 830 rows, 29 variables). The important variables include Points Allowed (PA), which represents the total number of points the defensive team gives up against the offensive line, Yards Allowed (Yds), which measures the total yards the opponents gains, Yards per Play Allowed (Y/P), which refers to how many yards per play the opponents gains. A few more important variables are Interceptions (Int), Touchdowns (TD), Sacks (Sk), and Tackles for Loss (TFL) where a large amount of values are season counts whereas a few are efficiency percentages (Int%, TD%).
#
#
# These specific metrics measure the overall performance of a strong team’s defensive line. In this project, PA and defensive statistics are relevant because a stronger team's defenses results beneficial towards MVP quarterbacks by allowing them better field positions and higher offensive opportunities.
# The dataset is not missing any values, and the data is clean. This is professional sports data so null values are practically non-existent since everything is recorded.

# %%
## Data Validation and Integrity Check: NFL Defensive & Opposition Stats
import pandas as pd 

# import os
# OG = pd.DataFrame()
# for path in os.listdir('./data/02-processed'):
#     if path == '.gitkeep':
#         continue
#     df = pd.read_csv('./data/02-processed/' + path)
#     OG = pd.concat([OG, df], axis=0)
# OG.to_csv('./data/00-raw/NFL_Opposition_and_Defensive_Stats.csv', index=False)

df = pd.read_csv('./data/00-raw/NFL_Opposition_and_Defensive_Stats.csv')
print(df.head(), '\n')
print('AS WE CAN SEE THROUGH df.head(), THE DATA IS TIDY SINCE EACH VARIABLE HAS ITS OWN COLUMN, EACH OBSERVATION HAS ITS OWN ROW, AND EACH VALUE HAS ITS OWN CELL. COLUMNS ARE UNIQUE\n')
print('Number of variables (columns) in dataset: ', df.shape[1], '\nNumber of observations (rows) in dataset: ', df.shape[0], '\n')
print('Missing data: ', df.isnull().sum().sum(), '\nWe have no missing data! There do not appear to be any outliers or suspicious entries either! The data appears to be very clean since \
      there are no missing values. However, the Tm (team name) column has an object dtype, not a string dtype, so I changed that below. (Easier to join the column when merging) \
      All other columns have appropriate dtypes, being floats and ints \n')
df['Tm'] = df['Tm'].astype('string')
print('Dtypes: ', df.dtypes.unique(), '\n')
df.to_csv('./data/02-processed/NFL_Opposition_and_Defensive_Stats.csv', index=False)
# Out:
#    Rk                   Tm   G   PA   Yds   Ply  Y/P  TO  FL  1stD  ...  TD.1  \
# 0   1     Baltimore Ravens  16  165  3967   924  4.3  49  26   216  ...     5
# 1   2     Tennessee Titans  16  191  3813   908  4.2  30  13   215  ...     7
# 2   3       Miami Dolphins  16  226  4636   995  4.7  41  13   289  ...     9
# 3   4  Philadelphia Eagles  16  245  4820  1055  4.6  31  12   295  ...    10
# 4   5      New York Giants  16  246  4546   988  4.6  31  11   274  ...     7
#
#    Y/A  1stD.2  Pen  Yds.3  1stPy   Sc%   TO%     EXP  Year
# 0  2.7      59   84    535     22  15.5  23.7  251.91  2000
# 1  3.6      62   97    778     19  18.1  13.8  196.89  2000
# 2  4.2      92   86    793     41  22.8  19.7  123.01  2000
# 3  4.0     105  111    936     31  25.1  14.9   90.34  2000
# 4  3.2      62   80    728     31  22.6  15.3   89.51  2000
#
# [5 rows x 29 columns]
#
# ...

# %% [markdown]
# ### Player Season and Career Stats (Dataset 4)
#
# This dataset contains the individual players seasons and career statistics from 2000-2025. Each row represents a player in one season (n = 2042 rows, 9 variables). The important variables that are included, Player name, Season, Age, Team, Games Played (G), Games Started (GS), Position (Pos) where these variables are measured in counts based on how many games each player played and started. These variables track quarterback performances every season with the teams defensive statistics resulting in focusing on the main MVP candidates of each season.
#
#
# The data is clean, and the dataset is not missing any values. There are no major concerns due to this being a professional sports data so null values are practically non-existent since everything is recorded.

# %%
## Processing Season & Player Career Stats: Validating Tidy Principles and String Normalization
import pandas as pd 

df = pd.read_csv('./data/00-raw/Player_Season_and_Career_Stats.csv')
print(df.head(), '\n')
print('AS WE CAN SEE THROUGH df.head(), THE DATA IS TIDY SINCE EACH VARIABLE HAS ITS OWN COLUMN, EACH OBSERVATION HAS ITS OWN ROW, AND EACH VALUE HAS ITS OWN CELL. COLUMNS ARE UNIQUE\n')
print('Number of variables (columns) in dataset: ', df.shape[1], '\nNumber of observations (rows) in dataset: ', df.shape[0], '\n')
print('Missing data: ', df.isnull().sum().sum(), '\nWe have no missing data! There do not appear to be any outliers or suspicious entries either! The data appears to be very clean since \
      there are no missing values. However, the Player (player name), Team (team city abbreviation), Pos (position of player), and Player-additional (player identifier) \
      columns have object dtypes, not string dtypes, so I changed them below. (Easier to join the column when merging) \
      All other columns have appropriate dtypes, being ints \n')
df['Player'] = df['Player'].astype('string')  
df['Team'] = df['Team'].astype('string') 
df['Pos'] = df['Pos'].astype('string') 
df['Player-additional'] = df['Player-additional'].astype('string') 
print('Dtypes: ', df.dtypes, '\n')
df.to_csv('./data/02-processed/Player_Season_and_Career_Stats.csv', index=False)
# Out:
#    Rk             Player  Season  Age Team   G  GS Pos Player-additional
# 0   1      Brandon Allen    2025   33  TEN   1   0  QB          AlleBr00
# 1   2         Josh Allen    2025   29  BUF  17  17  QB          AlleJo02
# 2   3         Kyle Allen    2025   29  DET   3   0  QB          AlleKy00
# 3   4       Tyson Bagent    2025   25  CHI   3   0  QB          BageTy00
# 4   5  Teddy Bridgewater    2025   33  TAM   4   0  QB          BridTe00
#
# AS WE CAN SEE THROUGH df.head(), THE DATA IS TIDY SINCE EACH VARIABLE HAS ITS OWN COLUMN, EACH OBSERVATION HAS ITS OWN ROW, AND EACH VALUE HAS ITS OWN CELL. COLUMNS ARE UNIQUE
#
# Number of variables (columns) in dataset:  9
# Number of observations (rows) in dataset:  2042
#
# Missing data:  0
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis

# %% [markdown]
# #### Dataset Merging and General Summary (Section 1 of EDA)
#
# In this section of EDA, we will merge our 4 datasets, and then plot/describe any noticeable trends that are found on the surface level. Tests for significance will be done in section 2 of EDA.

# %%
## Master Data Analysis: Relations of Player, Team, and MVP Statistics
import pandas as pd

NFL_Defense_Stats = pd.read_csv('./data/02-processed/NFL_Opposition_and_Defensive_Stats.csv') # Columns to join on: Tm (ex: New York Jets), Year (ex: 2000)
Player_Season_and_Career_Stats = pd.read_csv('./data/02-processed/Player_Season_and_Career_Stats.csv') # Columns to join on: Team (ex: NYJ), Season (ex: 2000)
QB_MVP_Votes = pd.read_csv('./data/02-processed/qb_mvp_votes.csv') # Columns to join on: Tm (ex: New York Jets), year (ex: 2000)
Season_Standings = pd.read_csv('./data/02-processed/season_standings.csv') # Columns to join on: Tm (ex: New York Jets), Year (ex: 2000)

# Convert abbreviations from Player_Season_and_Career_Stats to team names for joining
nfl_team_map = {
    # Standard team names
    "ARI": "Arizona Cardinals", "ATL": "Atlanta Falcons", "BAL": "Baltimore Ravens", "BUF": "Buffalo Bills", "CAR": "Carolina Panthers", "CHI": "Chicago Bears", "CIN": "Cincinnati Bengals",
    "CLE": "Cleveland Browns", "DAL": "Dallas Cowboys", "DEN": "Denver Broncos", "DET": "Detroit Lions", "GNB": "Green Bay Packers", "HOU": "Houston Texans", "IND": "Indianapolis Colts",
    "JAX": "Jacksonville Jaguars", "KAN": "Kansas City Chiefs", "LAC": "Los Angeles Chargers", "LAR": "Los Angeles Rams", "LVR": "Las Vegas Raiders", "MIA": "Miami Dolphins",
    "MIN": "Minnesota Vikings", "NOR": "New Orleans Saints", "NWE": "New England Patriots", "NYG": "New York Giants", "NYJ": "New York Jets", "PHI": "Philadelphia Eagles",
    "PIT": "Pittsburgh Steelers", "SEA": "Seattle Seahawks", "SFO": "San Francisco 49ers", "TAM": "Tampa Bay Buccaneers", "TEN": "Tennessee Titans", "WAS": "Washington Commanders",

    # Historical abbreviations (Teams that changed names due to changing cities)
    "OAK": "Oakland Raiders", "SDG": "San Diego Chargers", "STL": "St. Louis Rams",

    # Combined team abbreviations (SOME QUARTERBACKS HAVE MULTIPLE TEAMS DUE TO TRADES. WE PAY ATTENTION TO THE TEAM WHO RECEIVED THE PLAYER)
    "CINCLE": "Cleveland Browns", "MIANYG": "New York Giants", "NWEBAL": "Baltimore Ravens", "ARIMIN": "Minnesota Vikings", "CARLAR": "Los Angeles Rams",
    "NYJBAL": "Baltimore Ravens", "NWESFO": "San Francisco 49ers", "BUFDAL": "Dallas Cowboys", "CHIBAL": "Baltimore Ravens", "HOUSEA": "Seattle Seahawks",
    "HOUBAL": "Baltimore Ravens", "DALHOU": "Houston Texans", "CARCLE": "Cleveland Browns", "GNBOAK": "Oakland Raiders", "MINTAM": "Tampa Bay Buccaneers",
    "DENKAN": "Kansas City Chiefs", "BUFJAX": "Jacksonville Jaguars", "KANMIA": "Miami Dolphins", "OAKWAS": "Washington Commanders",
}
Player_Season_and_Career_Stats['Team'] = Player_Season_and_Career_Stats['Team'].map(nfl_team_map)
NFL_Defense_Stats['Tm'] = NFL_Defense_Stats['Tm'].replace({'Washington Football Team':'Washington Commanders', 'Washington Redskins': 'Washington Commanders'})
QB_MVP_Votes['Tm'] = QB_MVP_Votes['Tm'].replace({'Washington Football Team':'Washington Commanders', 'Washington Redskins': 'Washington Commanders'})
Season_Standings['Tm'] = Season_Standings['Tm'].replace({'Washington Football Team':'Washington Commanders', 'Washington Redskins': 'Washington Commanders'})

# G: Games played by this team
# Cmp: Average Percentage of passes completed by opponent offense against this team
# Yds: Yards gained by passing by opponent offense against this team
# TD: Passing touchdowns scored against this team
# Int: Number of interceptions thrown against this team (An interception occurs when the ball is caught by a defensive player, turning possession of the ball to the other team)
# Y/A: Average Yards gained per pass attempt by opponent
NFL_Defense_Stats = NFL_Defense_Stats[['Tm', 'Year', 'G', 'Cmp', 'Yds', 'TD', 'Int', 'Y/A']] # only gather relevant columns for the research question

# Player: Quarterback name
# Season: Year of the season 
# Age: Age of quarterback
# Team: Team name the quarterback played for
# G: Games played
Player_Season_and_Career_Stats = Player_Season_and_Career_Stats[['Player', 'Season', 'Age', 'Team', 'G']]

# Year: The NFL regular season year in which MVP voting occurred
# Player: Name of the player receiving MVP votes
# Pos: Player position (filtered to quarterbacks for this project)
# Tm: Team the player represented during that season
# 1st Place Votes: Number of first-place MVP votes received
# Share: Percentage of total possible MVP voting points earned by the player (value between 0 and 1). A value closer to 1 indicates stronger voter consensus, while values near 0 indicate minimal support. This variable will serve as the dependent variable in our analysis.
QB_MVP_Votes = QB_MVP_Votes[['year', 'Player', 'Pos', 'Tm', '1st_Place_Votes', 'Share', 'Rk']]
QB_MVP_Votes = QB_MVP_Votes.fillna(0.0)

# Tm: Team name for that season
# W: Number of games won during the regular season
# L: Number of games lost during the regular season
# T: Number of games tied (added beginning in 2002)
# W-L%: Winning percentage (wins divided by total games played)
# PF: Total points scored by the team during the regular season
# PA: Total points allowed by the team during the regular season
# PD: Point differential (points scored minus points allowed)
# MoV: Margin of Victory, the average point differential per game
# SoS: Strength of Schedule, measuring the average quality of opponents based on SRS values
# SRS: Simple Rating System, a composite metric estimating overall team strength in points above or below league average
# OSRS: Offensive Simple Rating System, estimating offensive contribution to team strength
# DSRS: Defensive Simple Rating System, estimating defensive contribution to team strength
Season_Standings = Season_Standings[['Tm', 'Year', 'W', 'L', 'T', 'W-L%', 'PF', 'PA', 'PD', 'MoV', 'SoS', 'SRS', 'OSRS', 'DSRS']]

# The length of merged_df should be equal to length of Player_Season_and_Career_Stats which means every quarterback for every year was assigned data
merged_df = Player_Season_and_Career_Stats.merge(NFL_Defense_Stats, left_on=['Team', 'Season'], right_on=['Tm', 'Year'], how='left')
merged_df = merged_df.merge(QB_MVP_Votes, left_on=['Tm', 'Year', 'Player'], right_on=['Tm', 'year', 'Player'], how='left')
merged_df = merged_df.merge(Season_Standings, left_on=['Tm', 'Year'], right_on=['Tm', 'Year'], how='left')
merged_df.drop(['year', 'Pos'], axis=1, inplace=True)
# merged_df['1st_Place_Votes'] = merged_df['1st_Place_Votes'].fillna(-1)

print('All quarterbacks assigned their team data? ', len(merged_df) == len(Player_Season_and_Career_Stats))
merged_df.head()

# merged_df[['1st_Place_Votes', 'Share']].head()
# Out:
# All quarterbacks assigned their team data?  True
#               Player  Season  Age                  Team  G_x  \
# 0      Brandon Allen    2025   33      Tennessee Titans    1
# 1         Josh Allen    2025   29         Buffalo Bills   17
# 2         Kyle Allen    2025   29         Detroit Lions    3
# 3       Tyson Bagent    2025   25         Chicago Bears    3
# 4  Teddy Bridgewater    2025   33  Tampa Bay Buccaneers    4
#
#                      Tm  Year  G_y  Cmp   Yds  ...  T   W-L%   PF   PA   PD  \
# 0      Tennessee Titans  2025   17  354  5867  ...  0  0.176  284  478 -194
# 1         Buffalo Bills  2025   17  277  4983  ...  0  0.706  481  365  116
# 2         Detroit Lions  2025   17  342  5642  ...  0  0.529  481  413   68
# 3         Chicago Bears  2025   17  355  6150  ...  0  0.647  441  415   26
# 4  Tampa Bay Buccaneers  2025   17  379  5733  ...  0  0.471  380  411  -31
#
#     MoV  SoS  SRS  OSRS  DSRS
# 0 -11.4  3.4 -8.0  -4.1  -3.9
# ...

# %%
merged_df.describe()
# Out:
#             Season          Age          G_x         Year          G_y  \
# count  2042.000000  2042.000000  2042.000000  2042.000000  2042.000000
# mean   2012.501469    28.395201     8.338883  2012.501469    16.201763
# std       7.604329     4.485158     5.638614     7.604329     0.401414
# min    2000.000000    21.000000     0.000000  2000.000000    16.000000
# 25%    2006.000000    25.000000     3.000000  2006.000000    16.000000
# 50%    2012.000000    27.000000     7.000000  2012.000000    16.000000
# 75%    2019.000000    31.000000    15.000000  2019.000000    16.000000
# max    2025.000000    45.000000    17.000000  2025.000000    17.000000
#
#                Cmp          Yds           TD          Int          Y/A  ...  \
# count  2042.000000  2042.000000  2042.000000  2042.000000  2042.000000  ...
# mean    336.425563  5441.449070    23.431929    14.633203     4.203624  ...
# std      38.938419   540.159909     5.630682     4.933873     0.427264  ...
# ...

# %%
## Visualizing the Relationship of Team Pass Defense vs. QB MVP Candidacy
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure()

dummy = merged_df.copy()
dummy['1st_Place_Votes'] = dummy['1st_Place_Votes'].fillna(-1)
dummy['1st_Place_Votes'] = dummy['1st_Place_Votes'].apply(lambda x: 'Top 3 MVP (QB)' if x > 0 else 'Not Top 3 MVP (QB)')

fig = sns.boxplot(
    data=dummy,
    x="1st_Place_Votes",
    y="Yds",
    #hue=""
)
plt.title('Team Pass Defense Performance vs. QB MVP Success (2000-2025)', fontsize=14, pad=15)
plt.xlabel('MVP Voting Status', fontsize=12)
plt.ylabel('Opponent Passing Yards Allowed (Season)', fontsize=12)

plt.show()

# %% [markdown]
# As we can see in the bar plot above, quarterbacks who received high shares of MVP votes have team defenses that allow less yards on average than team defenses with quarterbacks who received no/low shares of MVP votes. However, how do we know this observed difference is statistically significant and not due to random chance? This is the question we are setting out to answer in the next section of EDA, this time with additional variables.

# %%
# Tiny histograms to avoid visual clutter in the notebook
hist_cols = [
    'Age', 'Cmp', 'Yds', 'TD', 'Int',
    'W-L%', 'PF', 'PA', 'SoS', 'SRS', 'OSRS', 'DSRS'
 ]

plot_df = merged_df.copy()
plot_df['1st_Place_Votes'] = plot_df['1st_Place_Votes'].fillna(0)
plot_df['Share'] = plot_df['Share'].fillna(0)

n_cols = 4
n_rows = (len(hist_cols) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(8, 5), dpi=120)
axes = axes.flatten()

for i, col in enumerate(hist_cols):
    sns.histplot(
        data=plot_df,
        x=col,
        bins=20,
        ax=axes[i],
        color='#4C78A8',
        edgecolor=None
    )
    axes[i].set_title(col, fontsize=8)
    axes[i].tick_params(axis='both', labelsize=6)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

for j in range(len(hist_cols), len(axes)):
    axes[j].axis('off')

plt.tight_layout(pad=0.5)
plt.show()

# %% [markdown]
# As we can see in the histograms above, nearly all variables of importance are normally distributed, with the exception of age which is understandably right skewed since older players in the NFL are rare. However, this should not pose a problem to the rest of our calculations since age is not the focus of this project. What's more important is that variables like SoS (strength of schedule), DSRS (defensive contribution to team strength), and PA (total points allowed during regular season) are normal since we plan to run permutation tests on them later on.

# %% [markdown]
# #### Data Visualization and Statistical Testing (Section 2 EDA)
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## Correlation Heatmap across 5 variables test

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

cols_of_interest = ['Share', 'SoS', 'DSRS', 'PA', 'W-L%']
corr_data = merged_df[cols_of_interest].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_data, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt=".2f")
plt.title("Correlation Heatmap of Team Context Variables vs. MVP Vote Share")
plt.show()

# %% [markdown]
# This correlation heatmap visualizes the strength and direction of the linear relationships between various team/individual metrics and the Share of MVP votes received by a quarterback. The values, represented by the correlation coefficient r, range from -1 (perfect negative correlation) to +1 (perfect positive correlation).
#
# Simple Rating System (SRS) shows the strongest positive correlation with Vote Share (≈0.52). It suggests that overall team quality is the most significant factor linked to receiving MVP votes.
#
# Points Allowed (PA) has a notable negative correlation (≈−0.43). As a team's defense allows more points, the quarterback's MVP vote share tends to decrease, likely because defensive success correlates with the "wins" narrative.

# %%
###Filter out for Qbs who received votes towards MVP selection, anything greater than 0 will count and exclude Qbs who did not receive votes
merged_df['TD/Int'] = np.where(merged_df['Int'] != 0, merged_df['TD'] / merged_df['Int'], 0)

mvp_candidates = merged_df[merged_df['Share'] > 0].copy()

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

### Strength of Schedule vs Vote Share
sns.regplot(data=mvp_candidates, x='SoS', y='Share',
            ax=axes[0,0], scatter_kws={'alpha':0.6})
axes[0,0].set_title('Strength of Schedule vs. MVP Vote Share')
axes[0,0].set_xlabel('Strength of Schedule (SoS)')
axes[0,0].set_ylabel('MVP Vote Share')

### Defensive SRS vs Vote Share
sns.regplot(data=mvp_candidates, x='DSRS', y='Share',
            ax=axes[0,1], scatter_kws={'alpha':0.6}, color='green')
axes[0,1].set_title('Defensive Performance (DSRS) vs. MVP Vote Share')
axes[0,1].set_xlabel('Defensive Simple Rating System (DSRS)')
axes[0,1].set_ylabel('MVP Vote Share')

### Points Allowed vs Vote Share
sns.regplot(data=mvp_candidates, x='PA', y='Share',
            ax=axes[1,0], scatter_kws={'alpha':0.6}, color='red')
axes[1,0].set_title('Points Allowed vs. MVP Vote Share')
axes[1,0].set_xlabel('Points Allowed (PA)')
axes[1,0].set_ylabel('MVP Vote Share')

### TD/INT Ratio vs Vote Share
sns.regplot(data=mvp_candidates, x='TD/Int', y='Share',
            ax=axes[1,1], scatter_kws={'alpha':0.6}, color='purple')
axes[1,1].set_title('TD/INT Ratio vs. MVP Vote Share')
axes[1,1].set_xlabel('TD/INT Ratio')
axes[1,1].set_ylabel('MVP Vote Share')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Here all three plots have very similar scatters and lines of best fit with the exception of the TD/Int ratio (which is passing touchdowns divided by passing interceptions)  graph having a near-zero slope.
# * These graphs show a weakly positive correlation between the independent and dependent variables, meaning as SoS, DSRS, PA increase, so does the MVP vote share.
# * There does not seem to be a strong affect for TD/Int ratio, which is actually a great insight, showing us that overall team performance tends to have stronger predictive power than individual stats.

# %%
## Evaluating MVP Performance Context: Strength of Schedule, Defensive Support, and Passing Efficiency
dummy = merged_df.copy()
dummy['1st_Place_Votes'] = dummy['1st_Place_Votes'].fillna(-1)
dummy['MVP_Status'] = dummy['1st_Place_Votes'].apply(lambda x: 'Top 3 MVP (QB)' if x > 0 else 'Not Top 3')


fig, axes = plt.subplots(2, 2, figsize=(11,10))

###Strength of Schedule Boxplot test
sns.boxplot(data=dummy,x='MVP_Status',y='SoS',ax=axes[0,0],hue='MVP_Status',palette="Set1",legend=False)
axes[0,0].set_title('Strength of Schedule: Top 3 MVP Candidates vs Rest')
axes[0,0].set_ylabel('SoS')

###Defensive Simple Rating System Boxplot test 
sns.boxplot(data=dummy,x='MVP_Status',y='DSRS',ax=axes[0,1],hue='MVP_Status',palette="Set1",legend=False)
axes[0,1].set_title('Defensive SRS: Top 3 MVP Candidates vs Rest')
axes[0,1].set_ylabel('DSRS')

###Points Allowed Boxplot test
sns.boxplot(data=dummy,x='MVP_Status',y='PA',ax=axes[1,0],hue='MVP_Status',palette="Set1",legend=False)
axes[1,0].set_title('Points Allowed: Top 3 MVP Candidates vs Rest')
axes[1,0].set_ylabel('PA')

sns.boxplot(data=dummy[dummy['TD/Int']>0],x='MVP_Status',y='TD/Int',ax=axes[1,1],hue='MVP_Status',palette="Set1",legend=False)
axes[1,1].set_title('TD Pass to Interception Ratio: Top 3 MVP Candidates vs Rest')
axes[1,1].set_ylabel('PA')

plt.tight_layout()
plt.show()

# %% [markdown]
# * These boxplots show the distribution of the data, broken up again b/w Not Top 3 and Top 3 in MVP voter share
# * Again, distributions for the team stats (SoS, DSRS, PA) are very similar while TD/Int ratio is vastly different.
# * The thing that stands out the most is the outliers for TD/Int ratio. There are very many players who had relatively high TD/Int ratios but were not included in the Top 3 MVP Voting, which furthers our narrative that a player's stats are hardly ever the main reason for them to receive MVP votes.
# * We also see that SoS and PA are lower for Top 3 candidates. This is likely due to the idea that if a player plays worse teams (lower SoS), they win more. Further, teams that allow less points also tend to win more, providing reason that candidates who win are more likely to be voted.
# * Similar to team's allowing fewer points, if a team's DSRS is higher, they tend to give the offense more opportunities to score and make it much easier to win.

# %%
###Permutation tests are critical to see if there is an actual difference in strength of schedule, defensive simple rating score, and points allowed by defense between quarterbacks who are in top 3 MVP candidates versus those who are not

def run_permutation_test(df, col_to_test, group_col='MVP_Status', num_permutations=10000):
    """
    Runs a permutation test to see if there's a significant difference 
    in the mean of `col_to_test` between the two groups in `group_col`.
    """
    # Drop NaNs for the specific column to avoid calculation errors
    clean_df = df.dropna(subset=[col_to_test, group_col])
    
    # Calculate observed difference in means (Top 3 MVP - Not Top 3)
    group_means = clean_df.groupby(group_col)[col_to_test].mean()
    observed_diff = group_means['Top 3 MVP (QB)'] - group_means['Not Top 3']
    
    # Array to store permuted differences
    permuted_diffs = np.zeros(num_permutations)
    
    # Extract the values to shuffle
    values = clean_df[col_to_test].values
    labels = clean_df[group_col].values
    
    # Run the permutations
    for i in range(num_permutations):
        shuffled_labels = np.random.permutation(labels)
        
        # Calculate mean for the "shuffled" Top 3 group
        top3_mask = (shuffled_labels == 'Top 3 MVP (QB)')
        mean_top3 = np.mean(values[top3_mask])
        mean_not_top3 = np.mean(values[~top3_mask])
        
        permuted_diffs[i] = mean_top3 - mean_not_top3
        
    # Calculate p-value (two-tailed)
    p_value = np.sum(np.abs(permuted_diffs) >= np.abs(observed_diff)) / num_permutations
    
    print(f"--- Permutation Test Results for {col_to_test} ---")
    print(f"Observed Difference in Means: {observed_diff:.3f}")
    print(f"P-value: {p_value:.4f}")
    if p_value < 0.001:
        print("Result is statistically significant (p < 0.05). Reject the null hypothesis.\n")
    else:
        print("Result is not statistically significant. Fail to reject the null hypothesis.\n")
        
    return observed_diff, permuted_diffs, p_value

# Run tests on your variables
obs_diff_sos, perm_diffs_sos, p_sos = run_permutation_test(dummy, 'SoS')
obs_diff_dsrs, perm_diffs_dsrs, p_dsrs = run_permutation_test(dummy, 'DSRS')
obs_diff_pa, perm_diffs_pa, p_pa = run_permutation_test(dummy, 'PA')
obs_diff_td_int, perm_diffs_td_int, p_td_int = run_permutation_test(dummy, 'TD/Int')
# Out:
# --- Permutation Test Results for SoS ---
# Observed Difference in Means: -0.696
# P-value: 0.0000
# Result is statistically significant (p < 0.05). Reject the null hypothesis.
#
# --- Permutation Test Results for DSRS ---
# Observed Difference in Means: 1.510
# P-value: 0.0004
# Result is statistically significant (p < 0.05). Reject the null hypothesis.
#
# --- Permutation Test Results for PA ---
# Observed Difference in Means: -34.579
# P-value: 0.0000
# Result is statistically significant (p < 0.05). Reject the null hypothesis.
#
# --- Permutation Test Results for TD/Int ---
# Observed Difference in Means: -0.410
# P-value: 0.0085
# Result is not statistically significant. Fail to reject the null hypothesis.

# %% [markdown]
# * With a p value cutoff set to 0.001, we find that only the metrics that evaluate team performance show significance
# * This backs up what we saw in the graphs above: that MVP voter share is much more dependent on how well a player's team does than their own individual performance

# %% [markdown]
# ### ETC AD NASEUM
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
# - [X] **A.1 Informed consent - x**
# This project uses publicly available, aggregated NFL statistics and MVP voting data. No human subjects are directly involved, and no data were collected through surveys or direct interaction, so informed consent is not applicable.
#
# - [X] **A.2 Collection bias - x**
# Bias may arise from MVP voting itself, as votes are cast by media members and may reflect narrative preferences, market size, or team success rather than purely on-field performance. This limitation is acknowledged and motivates the use of vote share as an outcome rather than treating MVP voting as an objective measure of player value.
#
# - [X] **A.3 Limit PII exposure - x**
# The dataset contains only publicly available professional information about NFL players and teams and does not include sensitive or personally identifiable information beyond names and team affiliations.
#
# - [ ] **A.4 Downstream bias mitigation - x**
#
# ### B. Data Storage
# - [X] **B.1 Data security - x**
# All data used are publicly accessible and stored locally for academic purposes only. No sensitive or private data are stored.
#
# - [ ] **B.2 Right to be forgotten - x**
# - [ ] **B.3 Data retention plan - x**
#
# ### C. Analysis
# - [X] **C.1 Missing perspectives - x**
# This analysis focuses on quantitative team-context variables and does not capture subjective factors such as media narratives or voter motivations. These blind spots are acknowledged as limitations when interpreting results.
#
# - [X] **C.2 Dataset bias - x**
# Potential sources of bias include omitted variables and confounding between team success and MVP voting. These issues will be discussed as threats to validity rather than fully eliminated.
#
# - [X] **C.3 Honest representation - x**
# Visualizations and summary statistics will be presented in ways that accurately reflect the underlying data and avoid implying causal relationships where only associations are measured.
#
# - [X] **C.4 Privacy in analysis - x**
# No private or sensitive personal data are used or displayed in the analysis.
#
# - [X] **C.5 Auditability - x**
# The data collection, cleaning, and analysis steps will be documented and reproducible.
#
# ### D. Modeling
# - [X] **D.1 Proxy discrimination - x**
# The model relies on team and performance-based variables and does not include proxies for protected characteristics.
#
# - [ ] **D.2 Fairness across groups - x**
#
# - [X] **D.3 Metric selection -x**
# MVP vote share is used as the primary outcome, and its limitations as a subjective metric are explicitly acknowledged.
#
# - [X] **D.4 Explainability - x**
# The statistical models used are interpretable, allowing clear explanation of how each variable relates to MVP vote share.
#
# - [X] **D.5 Communicate limitations - x**
# All assumptions, limitations, and potential biases will be clearly communicated in the final report.
#
# ### E. Deployment
# - [ ] **E.1 Monitoring and evaluation - x**
# - [ ] **E.2 Redress - x**
# - [ ] **E.3 Roll back - x**
#
# - [X] **E.4 Unintended use - x**
# This analysis is intended solely for academic purposes and not for real-world decision-making such as player evaluation or contract negotiation.

# %% [markdown]
# ## Discussion and Conclusion
# This project set out to find out how much team factors like defensive performance, offensive line protection, and strength of schedule affect the share of MVP votes that NFL quarterbacks receive. We found that, even though the Most Valuable Player award is meant to honor individuals, voting is closely tied to the team around each candidate. Our permutation tests showed that stats like points allowed (PA) and the team’s Simple Rating System (SRS) are strongly linked to MVP vote share. On the other hand, the usual individual stat, touchdown-to-interception ratio, was not as significant in our tests when comparing the Top 3 candidates to everyone else.
#
# These results speak directly to the debate about whether the MVP award measures a quarterback’s individual skill or the environment around them. We pointed out that quarterbacks often get a boost from strong offensive lines or easier schedules, as seen with past winners like Aaron Rodgers. By looking at data from 2000 to 2025, we found that team stats like defensive efficiency and points allowed, which are often ignored, are actually strong predictors of who finishes in the Top 3 for MVP voting.
#
# The main takeaway from this study is that the NFL MVP award is more about team success centered on the quarterback than just individual stats. A strong defense that gives the offense good field position and more chances to score makes it much easier for a quarterback to win MVP. While great individual stats are still needed, our data shows that vote share is often secured by the team’s overall strength in all parts of the game.
#
# Still, there are some confusing points worth mentioning. Team performance was the main predictor, but it didn’t explain all the differences in voting. Sometimes, quarterbacks on teams with average defenses or tough schedules still get a lot of votes. This probably happens because the 50-person media panel is also swayed by factors like media stories, leadership, or standout performances in big moments, which our team stats can’t fully measure.
#
# There are a few limitations to our work. First, our data mostly covers quarterbacks who got MVP votes, not all starting quarterbacks, which could cause selection bias. Also, our team stats look at the whole season based on offensive and defensive performance, but not special teams. While special teams are often overlooked in the NFL, a special teams performance can make or break how well the offense starts and how opponents begin their drives. The switch to ranked-choice voting in 2022 also changed how votes are counted compared to earlier years. Finally, because there are only a few Top 3 finishers each year, it’s hard to use more complex models without overfitting.
#
# If this research continues, the next step would be to use more detailed, game-level data. This could show how well quarterbacks play against top teams affects how voters view them late in the season. We could also look at more stats for teammates, like catch rate and yards after catch for receivers. Finally, using sentiment analysis on end-of-season sports articles might help measure the impact of the narrative, which remains one of the strongest but hardest-to-define factors in the MVP race.
